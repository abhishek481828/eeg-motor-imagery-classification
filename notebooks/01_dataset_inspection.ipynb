# %% [markdown]
# # 01. PhysioNet EEG Motor Imagery Dataset Inspection
#
# This notebook inspects EDF file structures, channel names, sampling frequencies, duration, and annotation event codes for the PhysioNet dataset.

# %%
import mne
from pathlib import Path
from eeg_mi.data.edf_reader import EDFReader

data_dir = Path('../data/raw/physionet')
print(f"Raw data directory: {data_dir.resolve()}")
